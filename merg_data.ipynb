# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('explicacoes_trecho_código.csv', sep =';')
df2 = pd.read_csv('correctXincorrect_vinicius_2.csv', sep =';')

# %%
df2
# Out:
#     Code Snippet  Developer           Explanation Had Difficulty
# 0              2          1               Correto          False
# 1              2          2  Parcialmente Correto           True
# 2              2          3             Incorreto           True
# 3              2          4  Parcialmente Correto          False
# 4              2          5             Incorreto           True
# ..           ...        ...                   ...            ...
# 67            13          2                   NaN            NaN
# 68            13          3             Incorreto          False
# 69            13          4               Correto          False
# 70            13          5             Incorreto          False
# 71            13          6               Correto           True
#
# [72 rows x 4 columns]

# %%
df
# Out:
#     Code Snippet  Developer  \
# 0              2          1
# 1              2          2
# 2              2          3
# 3              2          4
# 4              2          5
# ..           ...        ...
# 67            13          2
# 68            13          3
# 69            13          4
# 70            13          5
# 71            13          6
#
#                                  Explicação do Código  \
# 0   Este método 'write' na classe 'CharacterDefini...
# 1   Este método 'write' na classe 'CharacterDefini...
# 2   Este método 'write' na classe 'CharacterDefini...
# 3   Este método 'write' na classe 'CharacterDefini...
# 4   Este método 'write' na classe 'CharacterDefini...
# ..                                                ...
# 67  Esta é uma classe abstrata Builder dentro de u...
# 68  Esta é uma classe abstrata Builder dentro de u...
# 69  Esta é uma classe abstrata Builder dentro de u...
# 70  Esta é uma classe abstrata Builder dentro de u...
# ...

# %%
merged_df = pd.merge(df, df2, on=['Code Snippet', 'Developer'])

# %%
merged_df
# Out:
#     Code Snippet  Developer  \
# 0              2          1
# 1              2          2
# 2              2          3
# 3              2          4
# 4              2          5
# ..           ...        ...
# 67            13          2
# 68            13          3
# 69            13          4
# 70            13          5
# 71            13          6
#
#                                  Explicação do Código  \
# 0   Este método 'write' na classe 'CharacterDefini...
# 1   Este método 'write' na classe 'CharacterDefini...
# 2   Este método 'write' na classe 'CharacterDefini...
# 3   Este método 'write' na classe 'CharacterDefini...
# 4   Este método 'write' na classe 'CharacterDefini...
# ..                                                ...
# 67  Esta é uma classe abstrata Builder dentro de u...
# 68  Esta é uma classe abstrata Builder dentro de u...
# 69  Esta é uma classe abstrata Builder dentro de u...
# 70  Esta é uma classe abstrata Builder dentro de u...
# ...
